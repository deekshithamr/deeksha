# %% [markdown]
# <a href="https://colab.research.google.com/github/deekshithamr/deeksha/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in  range  (20):
    if i%2==0:
        print("fizz")
    else:
        print("buzz")
# Out:
# fizz
# buzz
# fizz
# buzz
# fizz
# buzz
# fizz
# buzz
# fizz
# buzz
# fizz
# buzz
# fizz
# buzz
# fizz
# buzz
# fizz
# buzz
# fizz
# buzz

# %%
for i in range (51,101,2):
    print(i)
# Out:
# 51
# 53
# 55
# 57
# 59
# 61
# 63
# 65
# 67
# 69
# 71
# 73
# 75
# 77
# 79
# 81
# 83
# 85
# 87
# 89
# 91
# 93
# 95
# 97
# 99

# %%
#def functions
def product(a,b):
    return a*b

    product(50,2)

# %%
def per(marks):
    return(marks/100)*10

    print(f"{per(800)}%")

# %% [markdown]
# qustion how to create the function to calcuate precentage and the give a place of advice on the basic of the marks they  have got

# %%
# Introduction to Nump
import numpy as np

# %%
l1 =[1,2,3,"str",True,3.4]

arr1 = np.array ([1,2,3,4,5,6])
print(arr1)
print(l1)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 'str', True, 3.4]
